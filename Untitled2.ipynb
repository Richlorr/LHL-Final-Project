# %%
# !git clone https://github.com/sicxu/Deep3DFaceRecon_pytorch.git
# Out:
# /bin/sh: 1: git: not found

# %%
# !ls Deep3DFaceRecon_pytorch/
# Out:
# BFM	   data			environment.yml  nvdiffrast  train.py
# LICENSE    data_preparation.py	images		 options     util
# README.md  datasets		models		 test.py

# %%
# !conda env update --file Deep3DFaceRecon_pytorch/environment.yml --prune
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.10
#   latest version: 4.12.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ...
# jedi 0.17.2: ########################################################### | 100%
# kiwisolver 1.3.1: ###################################################### | 100%
# yaml 0.1.7: ############################################################ | 100%
# networkx 2.5: ########################################################## | 100%
# pytorch 1.6.0: ######################################################### | 100%
# libblas 3.8.0: ######################################################### | 100%
# llvm-openmp 13.0.1: #################################################### | 100%
# zstd 1.5.2: ############################################################ | 100%
# decorator 5.1.1: ####################################################### | 100%
# ...
